# %%
import numpy as np
import pandas as pd

# %%
#string
country = ['India','pakisthan','USA','Nepal','srilanka']
pd.Series(country)
# Out:
# 0        India
# 1    pakisthan
# 2          USA
# 3        Nepal
# 4     srilanka
# dtype: object

# %%
#iinteger
runs=[12,45,60,54]
run_ser=pd.Series(runs)
print(run_ser)
# Out:
# 0    12
# 1    45
# 2    60
# 3    54
# dtype: int64

# %%
#custom index
marks=[67,67,78,56,34]
subj=['math','English','history','Science','hindi']
pd.Series(marks,index=subj)
# Out:
# math       67
# English    67
# history    78
# Science    56
# hindi      34
# dtype: int64

# %%
#setting a name
marks={
    'maths':67,
    'english':78,
    'marathi':78,
    'history':78,
    'hindi':68
}
mark_ser=pd.Series(marks,name='tushar')
mark_ser
# Out:
# maths      67
# english    78
# marathi    78
# history    78
# hindi      68
# Name: tushar, dtype: int64

# %%
mark_ser.size
# Out:
# 5

# %%
mark_ser.dtype
# Out:
# dtype('int64')

# %%
mark_ser.name
# Out:
# 'tushar'

# %%
mark_ser.is_unique
pd.Series([3,4,5,6,7]).is_unique
# Out:
# True

# %%
mark_ser.index
# Out:
# Index(['maths', 'english', 'marathi', 'history', 'hindi'], dtype='object')

# %%
mark_ser.values
# Out:
# array([67, 78, 78, 78, 68])

# %%
bm=pd.read_csv('indian movies.csv')
bm
# Out:
#                    Movie Name
# 0                 Dr. Shaitan
# 1                  Nadir Khan
# 2      Apna Sapna Money Money
# 3              Aag Aur Sholay
# 4                     Parivar
# ...                       ...
# 50597          Sulagte Armaan
# 50598                  Aranya
# 50599              Balayogini
# 50600                 Alajadi
# 50601             KA-99 B-333
#
# [50602 rows x 1 columns]

# %%
bm.tail(10)
# Out:
#              Movie Name
# 50592             Saaho
# 50593   Romeo in Sikkim
# 50594  Jai Santoshi Maa
# 50595       Aakhri Geet
# 50596       Prassthanam
# 50597    Sulagte Armaan
# 50598            Aranya
# 50599        Balayogini
# 50600           Alajadi
# 50601       KA-99 B-333

# %%
bm.size
# Out:
# 50602

# %%
bm.is_unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-b34c9a994804> in <cell line: 1>()
# ----> 1 bm.is_unique
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'is_unique'

# %%
bm.sample(10)
# Out:
#                           Movie Name
# 2267                         Chuzhal
# 24713                    Ko Hola Tyo
# 17155               Yeh Mohabbat Hai
# 37575           Andha Kuyil Needhana
# 21833            Shri Vishnu Bhagwan
# 34088  Pillaiyar Theru Kadaisi Veedu
# 29006                  Jai Jwala Maa
# 15036              Dorikithe Dongalu
# 21965                         Nikaah
# 35266                   Hope Aur Hum

# %%
bm.value_counts()
# Out:
# Movie Name
#  Alif Laila                  167
#  Coke Studio                  96
#  Madam Secretary              69
#  Dirilis: Ertugrul            52
#  Humsafar                     46
#                             ...
# Ide Naa Modati Premalekha      1
# Ideachi Kalpana                1
# Idekaddi Nyayam                1
# Idem Oorura Babu               1
# Äidin toive                    1
# Length: 42441, dtype: int64

# %%
bm.sort_values(ascending=False ,by ='indian movies').head(1).value[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-e5f29cfe883b> in <cell line: 1>()
# ----> 1 bm.sort_values(ascending=False ,by ='indian movies').head(1).value[0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6910
#    6911             by = by[0]
# -> 6912             k = self._get_label_or_level_values(by, axis=axis)
#    6913
#    6914             # need to rewrap column in Series to apply key function
#
# ...

# %%
firstmovie=bm.sort_values(ascending = True,by='Movie Name').head(1)

# %%
firstmovie
# Out:
#         Movie Name
# 20832   Alif Laila

# %%
bm.count()

# %%
bm.sum()
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of                    Movie Name
# 0                 Dr. Shaitan
# 1                  Nadir Khan
# 2      Apna Sapna Money Money
# 3              Aag Aur Sholay
# 4                     Parivar
# ...                       ...
# 50597          Sulagte Armaan
# 50598                  Aranya
# 50599              Balayogini
# 50600                 Alajadi
# 50601             KA-99 B-333
#
# [50602 rows x 1 columns]>

# %%
bm.mean()
# Out:
# <ipython-input-55-973551e6614d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bm.mean()
# Series([], dtype: float64)

# %%
#diabetes
dia  = pd.read_csv('diabetes.csv')
dia
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dia.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
dia.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
dia.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
dia.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
dia.var()
# Out:
# Pregnancies                    11.354056
# Glucose                      1022.248314
# BloodPressure                 374.647271
# SkinThickness                 254.473245
# Insulin                     13281.180078
# BMI                            62.159984
# DiabetesPedigreeFunction        0.109779
# Age                           138.303046
# Outcome                         0.227483
# dtype: float64

# %%
dia.sort_values(ascending =True,by = 'Glucose')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 502            6        0             68             41        0  39.0
# 349            5        0             80             32        0  41.0
# 342            1        0             68             35        0  32.0
# 182            1        0             74             20       23  27.7
# ..           ...      ...            ...            ...      ...   ...
# 228            4      197             70             39      744  36.7
# 408            8      197             74              0        0  25.9
# 8              2      197             70             45      543  30.5
# 561            0      198             66             32      274  41.3
# 661            1      199             76             43        0  42.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# ...
